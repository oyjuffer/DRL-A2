# %% [markdown]
# # Assignment 1 - CATCH
#
# Sources: \
# https://github.com/yxu1168/Reinforcement-Learning-DQN-for-ATARI-s-Pong-Game---TensorFlow-2.0-Keras/blob/master/Reinforcement_Learning_CNN_DQN_for_ATARI%E2%80%99s_Pong_Game.ipynb
#
# https://github.com/PacktPublishing/Hands-on-Reinforcement-Learning-with-PyTorch/blob/master/Section%203/3.5%20DQN%20with%20Pong.ipynb
#
# https://keras.io/examples/rl/deep_q_network_breakout/

# %% [markdown]
# ## Libraries

# %%
import random
import datetime

import matplotlib.pyplot as plt
import numpy as np
from skimage.transform import resize

from collections import deque

import tensorflow as tf
from tensorflow import keras

import pandas as pd

# %% [markdown]
# ## Catch

# %%
class CatchEnv():
    def __init__(self):
        self.size = 21
        self.image = np.zeros((self.size, self.size))
        self.state = []
        self.fps = 4
        self.output_shape = (84, 84)

    def reset_random(self):
        self.image.fill(0)
        self.pos = np.random.randint(2, self.size-2)
        self.vx = np.random.randint(5) - 2
        self.vy = 1
        self.ballx, self.bally = np.random.randint(self.size), 4
        self.image[self.bally, self.ballx] = 1
        self.image[-5, self.pos - 2:self.pos + 3] = np.ones(5)

        return self.step(2)[0]

    def step(self, action):
        def left():
            if self.pos > 3:
                self.pos -= 2
        def right():
            if self.pos < 17:
                self.pos += 2
        def noop():
            pass
        {0: left, 1: right, 2: noop}[action]()

        self.image[self.bally, self.ballx] = 0
        self.ballx += self.vx
        self.bally += self.vy
        if self.ballx > self.size - 1:
            self.ballx -= 2 * (self.ballx - (self.size-1))
            self.vx *= -1
        elif self.ballx < 0:
            self.ballx += 2 * (0 - self.ballx)
            self.vx *= -1
        self.image[self.bally, self.ballx] = 1

        self.image[-5].fill(0)
        self.image[-5, self.pos-2:self.pos+3] = np.ones(5)
    
        terminal = self.bally == self.size - 1 - 4
        reward = int(self.pos - 2 <= self.ballx <= self.pos + 2) if terminal else 0

        [self.state.append(resize(self.image, (84, 84))) for _ in range(self.fps - len(self.state) + 1)]
        self.state = self.state[-self.fps:]

        return np.transpose(self.state, [1, 2, 0]), reward, terminal

    def get_num_actions(self):
        return 3

    def reset(self):
        return self.reset_random()

    def state_shape(self):
        return (self.fps,) + self.output_shape

# %% [markdown]
# ## Experience Replay Buffer

# %%
class ReplayBuffer():
    def __init__(self):
        self.buffer = deque()# queue of trajectories. Newest trajectories are appended to tthe beginning
        self.max_size = 1e6 # maximum number of trajectories to store
    
    def add(self, data):
        if len(self.buffer) == self.max_size:
            self.buffer.pop()
            self.buffer.appendleft(data)
        else:
            self.buffer.appendleft(data)

    def sample(self, batch_size):
        indices = np.random.randint(len(self.buffer), size=batch_size)
        states, actions, rewards, states_next, terminals = [], [], [], [], []

        for i in indices:
            s, a, r, sn, t = self.buffer[i]
            states.append(s)
            actions.append(a)
            rewards.append(r)
            states_next.append(sn)
            terminals.append(t)
            
        return np.array(states), np.array(actions), np.array(rewards), np.array(states_next), np.array(terminals)

# %% [markdown]
# ## Deep Q Network

# %%
input_shape = (84, 84, 4)
num_actions = 3

def DQN_Model():
    model = tf.keras.models.Sequential([
        tf.keras.layers.Conv2D(32, kernel_size = 8, strides = 4, activation='relu', input_shape=input_shape),
        tf.keras.layers.Conv2D(64, kernel_size = 4, strides = 2, activation='relu'),
        tf.keras.layers.Conv2D(64, kernel_size = 3, strides = 1, activation='relu'),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dense(num_actions, activation="linear")
    ])
    
    return model

# %% [markdown]
# ## Hyperparameters
# Loads the hyperparameters for the agent and the environment from a csv file

# %%
if not 'hyperparams_file' in locals():
    hyperparams_file = "hyperparameters.xlsx"
hyper_params = pd.read_excel("params/{}".format(hyperparams_file))

# %% [markdown]
# ## Agent

# %%
optimizer = keras.optimizers.RMSprop(learning_rate=float(hyper_params["learning_rate"]), clipnorm=1.0)
loss_fn = keras.losses.mse

class Agent():
    def __init__(self):
        self.action_size = num_actions
        self.train_net = DQN_Model()
        self.target_net = DQN_Model()
        
        # hyperparameters
        self.batch_size = int(hyper_params["batch_size"])
        self.epsilon = float(hyper_params["epsilon"])
        self.epsilon_end = float(hyper_params["epsilon_end"])
        self.epsilon_decay = float(hyper_params["epsilon_decay"])
        self.gamma = float(hyper_params["gamma"])

    # select an action based on epsilon greedy method
    def action(self, state, evaluate):
        if np.random.rand() < self.epsilon and not evaluate:
            return random.randint(0, 2)
        else:
            return np.argmax(self.train_net(state))

    # decay epsilon
    def decay_epsilon(self):
        if self.epsilon > self.epsilon_end:
            self.epsilon -= self.epsilon_decay

    # train the model
    def train(self, replay_buffer):

        # sample from the experience replay buffer
        states, actions, rewards, states_next, terminals = replay_buffer.sample(self.batch_size)
        mask = tf.one_hot(actions, self.action_size) # used to format train_q into (32, 1) just like target_Q

        # GradientTape is a more customizable version of .fit()
        with tf.GradientTape() as tape:
            train_q = self.train_net(states)
            train_q = tf.reduce_sum(train_q * mask, axis=1)
            
            target_q = rewards + (1 - terminals) * self.gamma * tf.reduce_max(self.target_net(states_next), axis=1)
            
            loss = loss_fn(target_q, train_q)

        gradients = tape.gradient(loss, self.train_net.trainable_variables)
        optimizer.apply_gradients(zip(gradients, self.train_net.trainable_variables))

        return loss

    # update the target network by copying the weights from the train_network
    def update_target_network(self):
        self.target_net.set_weights(self.train_net.get_weights())

# %% [markdown]
# ## Main Loop

# %%
def run_environment():
    env = CatchEnv()
    agent = Agent()
    replay_buffer = ReplayBuffer()

    # hyperparameters
    n_episodes = int(hyper_params["n_episodes"]) # total number of episodes to run the environment
    n_evaluate = int(hyper_params["n_evaluate"]) # number of episodes for training/evaluating alternatively
    n_update = int(hyper_params["n_update"]) # number of training episodes after which the target network is updated
    
    cnt_evaluate = n_evaluate; cnt_update = n_update
    evaluate = False
    
    # trackers
    reward_tracker = []
    loss_tracker = []

    for episode in range(n_episodes):

        state = env.reset()
        terminal = False
        
        while not terminal:
            
            # agent takes an action
            action = agent.action(np.reshape(state, (1, 84, 84, 4)), evaluate)

            # generate the next frame based on the agent action
            state_next, reward, terminal = env.step(action)

            # add experience to replay buffer
            replay_buffer.add((state, action, reward, state_next, terminal))

            # update the current state
            state = state_next
            
        # train the agent
        if not evaluate:
            loss = agent.train(replay_buffer)
            loss_tracker.append(loss.numpy())
            
            # update the target network after n_update
            cnt_update -= 1
            if cnt_update == 0:
                cnt_update = n_update
                agent.update_target_network()

        # decay epsilon
        agent.decay_epsilon()
                
        cnt_evaluate -= 1
        if cnt_evaluate == 0:
            cnt_evaluate = n_evaluate
            evaluate = not evaluate

        # stats
        reward_tracker.append(reward)
        print("EPISODE: {} - Rewards: {} - Loss.avg(10):{:.5f} - Score.avg(10): {:.4f} - Evaluate: {}".format(episode,  
                                sum(reward_tracker), round(sum(loss_tracker[-10:])/10, 5), 
                                round(sum(reward_tracker[-10:])/10, 2), evaluate))

    return np.array(reward_tracker), np.array(loss_tracker)

# %% [markdown]
# # Run

# %%
rewards, loss = run_environment()
# Out:
# EPISODE: 0 - Rewards: 0 - Loss.avg(10):0.00012 - Score.avg(10): 0.0000 - Evaluate: False
# EPISODE: 1 - Rewards: 0 - Loss.avg(10):0.00097 - Score.avg(10): 0.0000 - Evaluate: False
# EPISODE: 2 - Rewards: 0 - Loss.avg(10):0.00103 - Score.avg(10): 0.0000 - Evaluate: False
# EPISODE: 3 - Rewards: 1 - Loss.avg(10):0.00107 - Score.avg(10): 0.1000 - Evaluate: False
# EPISODE: 4 - Rewards: 1 - Loss.avg(10):0.00108 - Score.avg(10): 0.1000 - Evaluate: False
# EPISODE: 5 - Rewards: 1 - Loss.avg(10):0.00109 - Score.avg(10): 0.1000 - Evaluate: False
# EPISODE: 6 - Rewards: 2 - Loss.avg(10):0.00110 - Score.avg(10): 0.2000 - Evaluate: False
# EPISODE: 7 - Rewards: 3 - Loss.avg(10):0.00720 - Score.avg(10): 0.3000 - Evaluate: False
# EPISODE: 8 - Rewards: 3 - Loss.avg(10):0.00994 - Score.avg(10): 0.3000 - Evaluate: False
# EPISODE: 9 - Rewards: 3 - Loss.avg(10):0.01500 - Score.avg(10): 0.3000 - Evaluate: True
# EPISODE: 10 - Rewards: 3 - Loss.avg(10):0.01500 - Score.avg(10): 0.3000 - Evaluate: True
# EPISODE: 11 - Rewards: 3 - Loss.avg(10):0.01500 - Score.avg(10): 0.3000 - Evaluate: True
# EPISODE: 12 - Rewards: 3 - Loss.avg(10):0.01500 - Score.avg(10): 0.3000 - Evaluate: True
# EPISODE: 13 - Rewards: 3 - Loss.avg(10):0.01500 - Score.avg(10): 0.2000 - Evaluate: True
# EPISODE: 14 - Rewards: 3 - Loss.avg(10):0.01500 - Score.avg(10): 0.2000 - Evaluate: True
# EPISODE: 15 - Rewards: 3 - Loss.avg(10):0.01500 - Score.avg(10): 0.2000 - Evaluate: True
# EPISODE: 16 - Rewards: 3 - Loss.avg(10):0.01500 - Score.avg(10): 0.1000 - Evaluate: True
# EPISODE: 17 - Rewards: 4 - Loss.avg(10):0.01500 - Score.avg(10): 0.1000 - Evaluate: True
# EPISODE: 18 - Rewards: 4 - Loss.avg(10):0.01500 - Score.avg(10): 0.1000 - Evaluate: True
# EPISODE: 19 - Rewards: 5 - Loss.avg(10):0.01500 - Score.avg(10): 0.2000 - Evaluate: False
# EPISODE: 20 - Rewards: 5 - Loss.avg(10):0.01524 - Score.avg(10): 0.2000 - Evaluate: False
# EPISODE: 21 - Rewards: 5 - Loss.avg(10):0.01445 - Score.avg(10): 0.2000 - Evaluate: False
# EPISODE: 22 - Rewards: 5 - Loss.avg(10):0.01673 - Score.avg(10): 0.2000 - Evaluate: False
# EPISODE: 23 - Rewards: 5 - Loss.avg(10):0.01674 - Score.avg(10): 0.2000 - Evaluate: False
# EPISODE: 24 - Rewards: 5 - Loss.avg(10):0.02261 - Score.avg(10): 0.2000 - Evaluate: False
# EPISODE: 25 - Rewards: 5 - Loss.avg(10):0.02453 - Score.avg(10): 0.2000 - Evaluate: False
# EPISODE: 26 - Rewards: 5 - Loss.avg(10):0.02468 - Score.avg(10): 0.2000 - Evaluate: False
# EPISODE: 27 - Rewards: 6 - Loss.avg(10):0.02130 - Score.avg(10): 0.2000 - Evaluate: False
# EPISODE: 28 - Rewards: 6 - Loss.avg(10):0.01870 - Score.avg(10): 0.2000 - Evaluate: False
# EPISODE: 29 - Rewards: 6 - Loss.avg(10):0.01369 - Score.avg(10): 0.1000 - Evaluate: True
# EPISODE: 30 - Rewards: 6 - Loss.avg(10):0.01369 - Score.avg(10): 0.1000 - Evaluate: True
# EPISODE: 31 - Rewards: 6 - Loss.avg(10):0.01369 - Score.avg(10): 0.1000 - Evaluate: True
# EPISODE: 32 - Rewards: 7 - Loss.avg(10):0.01369 - Score.avg(10): 0.2000 - Evaluate: True
# EPISODE: 33 - Rewards: 7 - Loss.avg(10):0.01369 - Score.avg(10): 0.2000 - Evaluate: True
# EPISODE: 34 - Rewards: 7 - Loss.avg(10):0.01369 - Score.avg(10): 0.2000 - Evaluate: True
# EPISODE:
- Score.avg(10): 0.1000 - Evaluate: True
# EPISODE: 273 - Rewards: 61 - Loss.avg(10):0.01549 - Score.avg(10): 0.1000 - Evaluate: True
# EPISODE: 274 - Rewards: 61 - Loss.avg(10):0.01549 - Score.avg(10): 0.1000 - Evaluate: True
# EPISODE: 275 - Rewards: 61 - Loss.avg(10):0.01549 - Score.avg(10): 0.1000 - Evaluate: True
# EPISODE: 276 - Rewards: 62 - Loss.avg(10):0.01549 - Score.avg(10): 0.2000 - Evaluate: True
# EPISODE: 277 - Rewards: 62 - Loss.avg(10):0.01549 - Score.avg(10): 0.2000 - Evaluate: True
# EPISODE: 278 - Rewards: 63 - Loss.avg(10):0.01549 - Score.avg(10): 0.3000 - Evaluate: True
# EPISODE: 279 - Rewards: 64 - Loss.avg(10):0.01549 - Score.avg(10): 0.4000 - Evaluate: False
# EPISODE: 280 - Rewards: 65 - Loss.avg(10):0.00975 - Score.avg(10): 0.5000 - Evaluate: False
# EPISODE: 281 - Rewards: 66 - Loss.avg(10):0.00948 - Score.avg(10): 0.6000 - Evaluate: False
# EPISODE: 282 - Rewards: 67 - Loss.avg(10):0.01251 - Score.avg(10): 0.6000 - Evaluate: False
# EPISODE: 283 - Rewards: 67 - Loss.avg(10):0.01311 - Score.avg(10): 0.6000 - Evaluate: False
# EPISODE: 284 - Rewards: 67 - Loss.avg(10):0.01509 - Score.avg(10): 0.6000 - Evaluate: False
# EPISODE: 285 - Rewards: 68 - Loss.avg(10):0.01758 - Score.avg(10): 0.7000 - Evaluate: False
# EPISODE: 286 - Rewards: 68 - Loss.avg(10):0.01470 - Score.avg(10): 0.6000 - Evaluate: False
# EPISODE: 287 - Rewards: 68 - Loss.avg(10):0.01194 - Score.avg(10): 0.6000 - Evaluate: False
# EPISODE: 288 - Rewards: 68 - Loss.avg(10):0.01142 - Score.avg(10): 0.5000 - Evaluate: False
# EPISODE: 289 - Rewards: 68 - Loss.avg(10):0.01477 - Score.avg(10): 0.4000 - Evaluate: True
# EPISODE: 290 - Rewards: 68 - Loss.avg(10):0.01477 - Score.avg(10): 0.3000 - Evaluate: True
# EPISODE: 291 - Rewards: 68 - Loss.avg(10):0.01477 - Score.avg(10): 0.2000 - Evaluate: True
# EPISODE: 292 - Rewards: 69 - Loss.avg(10):0.01477 - Score.avg(10): 0.2000 - Evaluate: True
# EPISODE: 293 - Rewards: 69 - Loss.avg(10):0.01477 - Score.avg(10): 0.2000 - Evaluate: True
# EPISODE: 294 - Rewards: 69 - Loss.avg(10):0.01477 - Score.avg(10): 0.2000 - Evaluate: True
# EPISODE: 295 - Rewards: 70 - Loss.avg(10):0.01477 - Score.avg(10): 0.2000 - Evaluate: True
# EPISODE: 296 - Rewards: 70 - Loss.avg(10):0.01477 - Score.avg(10): 0.2000 - Evaluate: True
# EPISODE: 297 - Rewards: 71 - Loss.avg(10):0.01477 - Score.avg(10): 0.3000 - Evaluate: True
# EPISODE: 298 - Rewards: 71 - Loss.avg(10):0.01477 - Score.avg(10): 0.3000 - Evaluate: True
# EPISODE: 299 - Rewards: 71 - Loss.avg(10):0.01477 - Score.avg(10): 0.3000 - Evaluate: False
# EPISODE: 300 - Rewards: 72 - Loss.avg(10):0.01738 - Score.avg(10): 0.4000 - Evaluate: False
# EPISODE: 301 - Rewards: 73 - Loss.avg(10):0.01816 - Score.avg(10): 0.5000 - Evaluate: False
# EPISODE: 302 - Rewards: 74 - Loss.avg(10):0.01596 - Score.avg(10): 0.5000 - Evaluate: False
# EPISODE: 303 - Rewards: 74 - Loss.avg(10):0.01793 - Score.avg(10): 0.5000 - Evaluate: False
# EPISODE: 304 - Rewards: 74 - Loss.avg(10):0.01742 - Score.avg(10): 0.5000 - Evaluate: False
# EPISODE: 305 - Rewards: 75 - Loss.avg(10):0.01840 - Score.avg(10): 0.5000 - Evaluate: False
# EPISODE: 306 - Rewards: 75 - Loss.avg(10):0.01770 - Score.avg(10): 0.5000 - Evaluate: False
# EPISODE: 307 - Rewards: 75 - Loss.avg(10):0.02186 - Score.avg(10): 0.4000 - Evaluate: False
# EPISODE: 308 - Rewards: 76 - Loss.avg(10):0.02563 - Score.avg(10): 0.5000 - Evaluate: False
# EPISODE: 309 - Rewards: 76 - Loss.avg(10):0.02477 - Score.avg(10): 0.5000 - Evaluate: True
# EPISODE: 310 - Rewards: 76 - Loss.avg(10):0.02477 - Score.avg(10): 0.4000 - Evaluate: True
# EPISODE:
- Score.avg(10): 0.3000 - Evaluate: True
# EPISODE: 455 - Rewards: 114 - Loss.avg(10):0.01451 - Score.avg(10): 0.3000 - Evaluate: True
# EPISODE: 456 - Rewards: 114 - Loss.avg(10):0.01451 - Score.avg(10): 0.2000 - Evaluate: True
# EPISODE: 457 - Rewards: 114 - Loss.avg(10):0.01451 - Score.avg(10): 0.2000 - Evaluate: True
# EPISODE: 458 - Rewards: 114 - Loss.avg(10):0.01451 - Score.avg(10): 0.1000 - Evaluate: True
# EPISODE: 459 - Rewards: 114 - Loss.avg(10):0.01451 - Score.avg(10): 0.1000 - Evaluate: False
# EPISODE: 460 - Rewards: 114 - Loss.avg(10):0.01467 - Score.avg(10): 0.1000 - Evaluate: False
# EPISODE: 461 - Rewards: 114 - Loss.avg(10):0.01709 - Score.avg(10): 0.1000 - Evaluate: False
# EPISODE: 462 - Rewards: 114 - Loss.avg(10):0.01721 - Score.avg(10): 0.1000 - Evaluate: False
# EPISODE: 463 - Rewards: 114 - Loss.avg(10):0.01784 - Score.avg(10): 0.1000 - Evaluate: False
# EPISODE: 464 - Rewards: 114 - Loss.avg(10):0.01543 - Score.avg(10): 0.1000 - Evaluate: False
# EPISODE: 465 - Rewards: 115 - Loss.avg(10):0.01478 - Score.avg(10): 0.1000 - Evaluate: False
# EPISODE: 466 - Rewards: 115 - Loss.avg(10):0.01343 - Score.avg(10): 0.1000 - Evaluate: False
# EPISODE: 467 - Rewards: 116 - Loss.avg(10):0.01371 - Score.avg(10): 0.2000 - Evaluate: False
# EPISODE: 468 - Rewards: 117 - Loss.avg(10):0.01312 - Score.avg(10): 0.3000 - Evaluate: False
# EPISODE: 469 - Rewards: 118 - Loss.avg(10):0.01250 - Score.avg(10): 0.4000 - Evaluate: True
# EPISODE: 470 - Rewards: 118 - Loss.avg(10):0.01250 - Score.avg(10): 0.4000 - Evaluate: True
# EPISODE: 471 - Rewards: 119 - Loss.avg(10):0.01250 - Score.avg(10): 0.5000 - Evaluate: True
# EPISODE: 472 - Rewards: 119 - Loss.avg(10):0.01250 - Score.avg(10): 0.5000 - Evaluate: True
# EPISODE: 473 - Rewards: 119 - Loss.avg(10):0.01250 - Score.avg(10): 0.5000 - Evaluate: True
# EPISODE: 474 - Rewards: 119 - Loss.avg(10):0.01250 - Score.avg(10): 0.5000 - Evaluate: True
# EPISODE: 475 - Rewards: 119 - Loss.avg(10):0.01250 - Score.avg(10): 0.4000 - Evaluate: True
# EPISODE: 476 - Rewards: 120 - Loss.avg(10):0.01250 - Score.avg(10): 0.5000 - Evaluate: True
# EPISODE: 477 - Rewards: 120 - Loss.avg(10):0.01250 - Score.avg(10): 0.4000 - Evaluate: True
# EPISODE: 478 - Rewards: 120 - Loss.avg(10):0.01250 - Score.avg(10): 0.3000 - Evaluate: True
# EPISODE: 479 - Rewards: 121 - Loss.avg(10):0.01250 - Score.avg(10): 0.3000 - Evaluate: False
# EPISODE: 480 - Rewards: 122 - Loss.avg(10):0.01154 - Score.avg(10): 0.4000 - Evaluate: False
# EPISODE: 481 - Rewards: 122 - Loss.avg(10):0.01070 - Score.avg(10): 0.3000 - Evaluate: False
# EPISODE: 482 - Rewards: 122 - Loss.avg(10):0.01391 - Score.avg(10): 0.3000 - Evaluate: False
# EPISODE: 483 - Rewards: 122 - Loss.avg(10):0.01422 - Score.avg(10): 0.3000 - Evaluate: False
# EPISODE: 484 - Rewards: 122 - Loss.avg(10):0.01381 - Score.avg(10): 0.3000 - Evaluate: False
# EPISODE: 485 - Rewards: 123 - Loss.avg(10):0.01557 - Score.avg(10): 0.4000 - Evaluate: False
# EPISODE: 486 - Rewards: 124 - Loss.avg(10):0.01524 - Score.avg(10): 0.4000 - Evaluate: False
# EPISODE: 487 - Rewards: 125 - Loss.avg(10):0.01327 - Score.avg(10): 0.5000 - Evaluate: False
# EPISODE: 488 - Rewards: 125 - Loss.avg(10):0.01440 - Score.avg(10): 0.5000 - Evaluate: False
# EPISODE: 489 - Rewards: 125 - Loss.avg(10):0.01562 - Score.avg(10): 0.4000 - Evaluate: True
# EPISODE: 490 - Rewards: 125 - Loss.avg(10):0.01562 - Score.avg(10): 0.3000 - Evaluate: True
# EPISODE: 491 - Rewards: 125 - Loss.avg(10):0.01562 - Score.avg(10): 0.3000 - Evaluate: True
# EPISODE: 492 - Rewards: 126 - Loss.avg(10):0.01562 - Score.avg(10): 0.4000 - Evaluate: True
# EPISODE: 493 - Rewards: 127 - Loss.avg(10):0.01562 - Score.avg(10): 0.5000 - Evaluate: True
# EPISODE: 494 - Rewards: 128 - Loss.avg(10):0.01562 - Score.avg(10): 0.6000 - Evaluate: True
# EPISODE: 495 - Rewards: 128 - Loss.avg(10):0.01562 - Score.avg(10): 0.5000 - Evaluate: True
# EPISODE: 496 - Rewards: 128 - Loss.avg(10):0.01562 - Score.avg(10): 0.4000 - Evaluate: True
# EPISODE: 497 - Rewards: 128 - Loss.avg(10):0.01562 - Score.avg(10): 0.3000 - Evaluate: True
# EPISODE: 498 - Rewards: 128 - Loss.avg(10):0.01562 - Score.avg(10): 0.3000 - Evaluate: True
# EPISODE: 499 - Rewards: 129 - Loss.avg(10):0.01562 - Score.avg(10): 0.4000 - Evaluate: False
# EPISODE: 500 - Rewards: 129 - Loss.avg(10):0.01546 - Score.avg(10): 0.4000 - Evaluate: False
# EPISODE: 501 - Rewards: 130 - Loss.avg(10):0.01539 - Score.avg(10): 0.5000 - Evaluate: False
# EPISODE: 502 - Rewards: 131 - Loss.avg(10):0.01463 - Score.avg(10): 0.5000 - Evaluate: False
# EPISODE: 503 - Rewards: 131 - Loss.avg(10):0.01419 - Score.avg(10): 0.4000 - Evaluate: False
# EPISODE: 504 - Rewards: 131 - Loss.avg(10):0.01465 - Score.avg(10): 0.3000 - Evaluate: False
# EPISODE: 505 - Rewards: 131 - Loss.avg(10):0.01349 - Score.avg(10): 0.3000 - Evaluate: False
# EPISODE: 506 - Rewards: 131 - Loss.avg(10):0.01535 - Score.avg(10): 0.3000 - Evaluate: False
# EPISODE: 507 - Rewards: 131 - Loss.avg(10):0.01660 - Score.avg(10): 0.3000 - Evaluate: False
# EPISODE: 508 - Rewards: 132 - Loss.avg(10):0.01555 - Score.avg(10): 0.4000 - Evaluate: False
# EPISODE: 509 - Rewards: 133 - Loss.avg(10):0.01499 - Score.avg(10): 0.4000 - Evaluate: True
# EPISODE: 510 - Rewards: 133 - Loss.avg(10):0.01499 - Score.avg(10): 0.4000 - Evaluate: True
# EPISODE: 511 - Rewards: 133 - Loss.avg(10):0.01499 - Score.avg(10): 0.3000 - Evaluate: True
# EPISODE: 512 - Rewards: 134 - Loss.avg(10):0.01499 - Score.avg(10): 0.3000 - Evaluate: True
# EPISODE: 513 - Rewards: 135 - Loss.avg(10):0.01499 - Score.avg(10): 0.4000 - Evaluate: True
# EPISODE: 514 - Rewards: 135 - Loss.avg(10):0.01499 - Score.avg(10): 0.4000 - Evaluate: True
# EPISODE: 515 - Rewards: 136 - Loss.avg(10):0.01499 - Score.avg(10): 0.5000 - Evaluate: True
# EPISODE: 516 - Rewards: 136 - Loss.avg(10):0.01499 - Score.avg(10): 0.5000 - Evaluate: True
# EPISODE: 517 - Rewards: 136 - Loss.avg(10):0.01499 - Score.avg(10): 0.5000 - Evaluate: True
# EPISODE: 518 - Rewards: 136 - Loss.avg(10):0.01499 - Score.avg(10): 0.4000 - Evaluate: True
# EPISODE: 519 - Rewards: 136 - Loss.avg(10):0.01499 - Score.avg(10): 0.3000 - Evaluate: False
# EPISODE: 520 - Rewards: 136 - Loss.avg(10):0.01502 - Score.avg(10): 0.3000 - Evaluate: False
# EPISODE: 521 - Rewards: 137 - Loss.avg(10):0.01384 - Score.avg(10): 0.4000 - Evaluate: False
# EPISODE: 522 - Rewards: 137 - Loss.avg(10):0.01191 - Score.avg(10): 0.3000 - Evaluate: False
# EPISODE: 523 - Rewards: 137 - Loss.avg(10):0.01246 - Score.avg(10): 0.2000 - Evaluate: False
# ...
# EPISODE: 4831 - Rewards: 3189 - Loss.avg(10):0.01049 - Score.avg(10): 0.9000 - Evaluate: True
# EPISODE: 4832 - Rewards: 3190 - Loss.avg(10):0.01049 - Score.avg(10): 0.9000 - Evaluate: True
# EPISODE: 4833 - Rewards: 3191 - Loss.avg(10):0.01049 - Score.avg(10): 0.9000 - Evaluate: True
# EPISODE: 4834 - Rewards: 3192 - Loss.avg(10):0.01049 - Score.avg(10): 0.9000 - Evaluate: True
# EPISODE: 4835 - Rewards: 3193 - Loss.avg(10):0.01049 - Score.avg(10): 0.9000 - Evaluate: True
# EPISODE: 4836 - Rewards: 3194 - Loss.avg(10):0.01049 - Score.avg(10): 0.9000 - Evaluate: True
# EPISODE: 4837 - Rewards: 3195 - Loss.avg(10):0.01049 - Score.avg(10): 0.9000 - Evaluate: True
# EPISODE: 4838 - Rewards: 3196 - Loss.avg(10):0.01049 - Score.avg(10): 1.0000 - Evaluate: True
# EPISODE: 
# EPISODE: 4911 - Rewards: 3265 - Loss.avg(10):0.01369 - Score.avg(10): 0.9000 - Evaluate: True
# EPISODE: 4912 - Rewards: 3266 - Loss.avg(10):0.01369 - Score.avg(10): 0.9000 - Evaluate: True
# EPISODE: 4913 - Rewards: 3267 - Loss.avg(10):0.01369 - Score.avg(10): 0.9000 - Evaluate: True
# EPISODE: 4914 - Rewards: 3268 - Loss.avg(10):0.01369 - Score.avg(10): 0.9000 - Evaluate: True
# EPISODE: 4915 - Rewards: 3269 - Loss.avg(10):0.01369 - Score.avg(10): 0.9000 - Evaluate: True
# EPISODE: 4916 - Rewards: 3270 - Loss.avg(10):0.01369 - Score.avg(10): 0.9000 - Evaluate: True
# EPISODE: 4917 - Rewards: 3270 - Loss.avg(10):0.01369 - Score.avg(10): 0.9000 - Evaluate: True
# EPISODE: 4918 - Rewards: 3271 - Loss.avg(10):0.01369 - Score.avg(10): 0.9000 - Evaluate: True
# EPISODE: 4919 - Rewards: 3272 - Loss.avg(10):0.01369 - Score.avg(10): 0.9000 - Evaluate: False
# EPISODE: 4920 - Rewards: 3273 - Loss.avg(10):0.01345 - Score.avg(10): 0.9000 - Evaluate: False
# EPISODE: 4921 - Rewards: 3273 - Loss.avg(10):0.01253 - Score.avg(10): 0.8000 - Evaluate: False
# EPISODE: 4922 - Rewards: 3274 - Loss.avg(10):0.01351 - Score.avg(10): 0.8000 - Evaluate: False
# EPISODE: 4923 - Rewards: 3275 - Loss.avg(10):0.01243 - Score.avg(10): 0.8000 - Evaluate: False
# EPISODE: 4924 - Rewards: 3276 - Loss.avg(10):0.01185 - Score.avg(10): 0.8000 - Evaluate: False
# EPISODE: 4925 - Rewards: 3277 - Loss.avg(10):0.01194 - Score.avg(10): 0.8000 - Evaluate: False
# EPISODE: 4926 - Rewards: 3278 - Loss.avg(10):0.01211 - Score.avg(10): 0.8000 - Evaluate: False
# EPISODE: 4927 - Rewards: 3279 - Loss.avg(10):0.01255 - Score.avg(10): 0.9000 - Evaluate: False
# EPISODE: 4928 - Rewards: 3280 - Loss.avg(10):0.01132 - Score.avg(10): 0.9000 - Evaluate: False
# EPISODE: 4929 - Rewards: 3281 - Loss.avg(10):0.01128 - Score.avg(10): 0.9000 - Evaluate: True
# EPISODE: 4930 - Rewards: 3282 - Loss.avg(10):0.01128 - Score.avg(10): 0.9000 - Evaluate: True
# EPISODE: 4931 - Rewards: 3283 - Loss.avg(10):0.01128 - Score.avg(10): 1.0000 - Evaluate: True
# EPISODE: 4932 - Rewards: 3284 - Loss.avg(10):0.01128 - Score.avg(10): 1.0000 - Evaluate: True
# EPISODE: 4933 - Rewards: 3285 - Loss.avg(10):0.01128 - Score.avg(10): 1.0000 - Evaluate: True
# EPISODE: 4934 - Rewards: 3286 - Loss.avg(10):0.01128 - Score.avg(10): 1.0000 - Evaluate: True
# EPISODE: 4935 - Rewards: 3287 - Loss.avg(10):0.01128 - Score.avg(10): 1.0000 - Evaluate: True
# EPISODE: 4936 - Rewards: 3288 - Loss.avg(10):0.01128 - Score.avg(10): 1.0000 - Evaluate: True
# EPISODE: 4937 - Rewards: 3289 - Loss.avg(10):0.01128 - Score.avg(10): 1.0000 - Evaluate: True
# EPISODE: 4938 - Rewards: 3290 - Loss.avg(10):0.01128 - Score.avg(10): 1.0000 - Evaluate: True
# EPISODE: 4939 - Rewards: 3291 - Loss.avg(10):0.01128 - Score.avg(10): 1.0000 - Evaluate: False
# EPISODE: 4940 - Rewards: 3292 - Loss.avg(10):0.01132 - Score.avg(10): 1.0000 - Evaluate: False
# EPISODE: 4941 - Rewards: 3293 - Loss.avg(10):0.01149 - Score.avg(10): 1.0000 - Evaluate: False
# EPISODE: 4942 - Rewards: 3294 - Loss.avg(10):0.01180 - Score.avg(10): 1.0000 - Evaluate: False
# EPISODE: 
# EPISODE: 4985 - Rewards: 3335 - Loss.avg(10):0.00926 - Score.avg(10): 0.8000 - Evaluate: False
# EPISODE: 4986 - Rewards: 3336 - Loss.avg(10):0.00826 - Score.avg(10): 0.9000 - Evaluate: False
# EPISODE: 4987 - Rewards: 3337 - Loss.avg(10):0.00798 - Score.avg(10): 0.9000 - Evaluate: False
# EPISODE: 4988 - Rewards: 3338 - Loss.avg(10):0.00668 - Score.avg(10): 0.9000 - Evaluate: False
# EPISODE: 4989 - Rewards: 3339 - Loss.avg(10):0.00820 - Score.avg(10): 0.9000 - Evaluate: True
# EPISODE: 4990 - Rewards: 3340 - Loss.avg(10):0.00820 - Score.avg(10): 0.9000 - Evaluate: True
# EPISODE: 4991 - Rewards: 3341 - Loss.avg(10):0.00820 - Score.avg(10): 0.9000 - Evaluate: True
# EPISODE: 4992 - Rewards: 3342 - Loss.avg(10):0.00820 - Score.avg(10): 1.0000 - Evaluate: True
# EPISODE: 4993 - Rewards: 3343 - Loss.avg(10):0.00820 - Score.avg(10): 1.0000 - Evaluate: True
# EPISODE: 4994 - Rewards: 3344 - Loss.avg(10):0.00820 - Score.avg(10): 1.0000 - Evaluate: True
# EPISODE: 4995 - Rewards: 3345 - Loss.avg(10):0.00820 - Score.avg(10): 1.0000 - Evaluate: True
# EPISODE: 4996 - Rewards: 3346 - Loss.avg(10):0.00820 - Score.avg(10): 1.0000 - Evaluate: True
# EPISODE: 4997 - Rewards: 3347 - Loss.avg(10):0.00820 - Score.avg(10): 1.0000 - Evaluate: True
# EPISODE: 4998 - Rewards: 3348 - Loss.avg(10):0.00820 - Score.avg(10): 1.0000 - Evaluate: True
# EPISODE: 4999 - Rewards: 3348 - Loss.avg(10):0.00820 - Score.avg(10): 0.9000 - Evaluate: False

# %% [markdown]
# ## Save Results

# %%
reward_avg_train = []; reward_avg_eval = []
loss_avg_train = []; loss_avg_eval = []

n_episodes = int(hyper_params["n_episodes"]); n_evaluate = int(hyper_params["n_evaluate"])
for ii in range(0, n_episodes, n_evaluate*2):
    reward_avg_train.append(np.mean(rewards[ii:(ii + n_evaluate)]))
    reward_avg_eval.append(np.mean(rewards[(ii + n_evaluate):(ii + n_evaluate*2)]))
    
    loss_avg_train.append(np.mean(loss[ii:(ii + n_evaluate)]))
    loss_avg_eval.append(np.mean(loss[(ii + n_evaluate):(ii + n_evaluate*2)]))

if not 'output_name' in locals():
    output_name = datetime.datetime.now().strftime("%d_%H-%M-%S")

np.save('results/rewards/train_{}.npy'.format(output_name), reward_avg_train)
np.save('results/rewards/eval_{}.npy'.format(output_name), reward_avg_eval)

np.save('results/submission/group_01_catch_rewards_5.npy', reward_avg_eval)

np.save('results/loss/train_{}.npy'.format(output_name), loss_avg_train)
np.save('results/loss/eval_{}.npy'.format(output_name), loss_avg_eval)

# %%
import os

rr = []
for file in os.listdir("results/submission/"):
    df = np.load("results/submission/"+file)
    rr.append(df)


plt.plot(np.mean(rr, axis=0))

# %% [markdown]
# ## Inspect Results

# %%
plt.figure(figsize=(12,6))
plt.plot(reward_avg_eval)
plt.xlabel(f"average of {n_evaluate} evaluate episodes")
plt.ylabel("score")
plt.ylim(0, 1)
plt.show()

# plt.figure(figsize=(12,6))
# plt.plot(loss_avg_eval)
# plt.xlabel(f"average of {n_evaluate} evaluate episodes")
# plt.ylabel("loss")
# plt.show()
